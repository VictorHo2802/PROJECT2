# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error, mean_absolute_error
from datetime import datetime as dt
import warnings

import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/Users/macbook/Desktop/TAXI_PRICE_EXTENSION/DATA/TREASURY STATMENT/IntExp_20200501_20250430.csv', parse_dates=['Record Date'])

# %%
df.head()
# Out:
#   Record Date       Expense Category Description Expense Group Description  \
# 0  2025-04-30  INTEREST EXPENSE ON PUBLIC ISSUES  ACCRUED INTEREST EXPENSE
# 1  2025-04-30  INTEREST EXPENSE ON PUBLIC ISSUES  ACCRUED INTEREST EXPENSE
# 2  2025-04-30  INTEREST EXPENSE ON PUBLIC ISSUES  ACCRUED INTEREST EXPENSE
# 3  2025-04-30  INTEREST EXPENSE ON PUBLIC ISSUES  ACCRUED INTEREST EXPENSE
# 4  2025-04-30  INTEREST EXPENSE ON PUBLIC ISSUES  ACCRUED INTEREST EXPENSE
#
#                      Expense Type Description  Current Month Expense Amount  \
# 0                              Treasury Notes                  3.546727e+10
# 1                              Treasury Bonds                  1.307165e+10
# 2       Inflation Protected Securities (TIPS)                  1.716649e+09
# 3  Int. Expense Inflation Compensation (TIPS)                  9.073429e+09
# 4          Treasury Floating Rate Notes (FRN)                  2.414923e+09
#
#    Fiscal Year to Date Expense Amount
# 0                        2.367258e+11
# 1                        8.886390e+10
# 2                        1.166356e+10
# 3                        2.875103e+10
# 4                        1.645376e+10
