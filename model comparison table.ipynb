# %% [markdown]
# **Bảng So Sánh Chi Tiết Các Mô Hình Machine Learning**
#
# **Kết Quả Phân Tích Rủi Ro Tín Dụng**
#
# |                     |                    |                          |                |               |                     |            |            |
# |---------|---------|---------|---------|---------|---------|---------|---------|
# | Mô hình             | Loại               | Thời gian huấn luyện (s) | Validation AUC | Validation F1 | Validation Accuracy | Precision  | Recall     |
# | **Random Forest**   | Không truyền thống | 0.796                    | **0.9280**     | **0.8987**    | **85.45%**          | 0.8787     | **0.9196** |
# | Logistic Regression | Truyền thống       | 0.009                    | 0.9114         | 0.8882        | 84.19%              | **0.8812** | 0.8952     |
# | Neural Network      | Không truyền thống | 10.837                   | 0.8976         | 0.8695        | 81.81%              | 0.8755     | 0.8635     |
#
# **Top 5 Đặc Trưng Quan Trọng Nhất (Random Forest)**
#
# |          |                        |                |                                      |
# |------------------|------------------|------------------|------------------|
# | Thứ hạng | Đặc trưng              | Tầm quan trọng | Ý nghĩa                              |
# | 1        | CREDIT_HISTORY         | 24.41%         | Lịch sử tín dụng của khách hàng      |
# | 2        | LOAN_TO_INCOME         | 19.41%         | Tỷ lệ khoản vay trên thu nhập        |
# | 3        | CREDIT_AGE_INTERACTION | 15.38%         | Tương tác giữa điểm tín dụng và tuổi |
# | 4        | LOAN_AMOUNT            | 11.03%         | Số tiền vay                          |
# | 5        | INCOME                 | 8.66%          | Thu nhập của khách hàng              |
#
# **Phân Phối Khách Hàng Theo Mức Độ Rủi Ro**
#
# |                       |                     |           |                               |
# |------------------|------------------|------------------|------------------|
# | Mức độ rủi ro         | Số lượng khách hàng | Tỷ lệ (%) | Khuyến nghị                   |
# | Low Risk (\<0.3)      | 255 khách hàng      | 18.9%     | Phê duyệt với điều kiện chuẩn |
# | Medium Risk (0.3-0.7) | 292 khách hàng      | 21.7%     | Xem xét kỹ lưỡng              |
# | High Risk (\>0.7)     | 800 khách hàng      | 59.4%     | Từ chối hoặc yêu cầu đảm bảo  |
#
# **Confusion Matrix - Random Forest (Mô hình tốt nhất)**
#
# |          |             |             |
# |----------|-------------|-------------|
# |          | Predicted 0 | Predicted 1 |
# | Actual 0 | 282         | 120         |
# | Actual 1 | 76          | 869         |
#
# -   **True Negatives**: 282
#
# -   **False Positives**: 120
#
# -   **False Negatives**: 76
#
# -   **True Positives**: 869
#
# -   **Specificity (TNR)**: 0.7015
#
# -   **Sensitivity (TPR)**: 0.9196
#
# **Kết Luận**
#
#  **Random Forest** được khuyến nghị là mô hình tối ưu với:
#
# -   AUC-ROC cao nhất: **0.9280**
#
# -   F1-Score cao nhất: **0.8987**
#
# -   Accuracy: **85.45%**
#
# -   Thời gian huấn luyện hợp lý: **0.796 giây**
#
#  **CREDIT_HISTORY** (24.41%) và **LOAN_TO_INCOME** (19.41%) là 2 yếu
# tố quan trọng nhất trong dự đoán rủi ro tín dụng.
#
#  Mô hình phân loại được **59.4%** khách hàng vào nhóm High Risk, cần
# xem xét kỹ lưỡng trong quyết định cho vay.
